# %% [markdown]
# <a href="https://colab.research.google.com/github/tanmayrathi/ML-PRACTICAL/blob/main/ML_CS23032_Lab7_Extra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tanmay Rathi Assignment 7

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path="/content/drive/MyDrive/ML_Data/Student_Performance_dataset_5000 - Student_Performance_dataset_5000.csv"
df=pd.read_csv(path)
df.head(5)
# Out:
#    student_id  age gender academic_level  study_hours  self_study_hours  \
# 0           1   18  Other    High School         7.64              1.56
# 1           2   18  Other    High School         2.21              2.22
# 2           3   22   Male    High School         3.45              0.00
# 3           4   17  Other    High School         5.75              2.08
# 4           5   19  Other    High School         6.83              1.72
#
#    online_classes_hours  social_media_hours  gaming_hours  sleep_hours  ...  \
# 0                  2.20                3.05          2.19         6.52  ...
# 1                  2.10                1.65          2.55         5.97  ...
# 2                  0.29                1.34          2.08         8.39  ...
# 3                  3.01                2.27          2.20         6.31  ...
# 4                  3.33                2.65          0.70         8.01  ...
#
# ...

# %%
df.shape
# Out:
# (5000, 21)

# %%
df.describe()
# Out:
#         student_id          age  study_hours  self_study_hours  \
# count  5000.000000  5000.000000  5000.000000       5000.000000
# mean   2500.500000    20.520400     4.539594          2.478734
# std    1443.520003     2.870406     1.821665          1.177990
# min       1.000000    16.000000     0.000000          0.000000
# 25%    1250.750000    18.000000     3.250000          1.660000
# 50%    2500.500000    20.000000     4.530000          2.480000
# 75%    3750.250000    23.000000     5.760000          3.290000
# max    5000.000000    25.000000    11.840000          7.410000
#
#        online_classes_hours  social_media_hours  gaming_hours  sleep_hours  \
# count           5000.000000         5000.000000   5000.000000  5000.000000
# mean               2.011984            2.998086      1.564514     7.016492
# std                0.983906            1.467949      1.110807     1.163692
# min                0.000000            0.000000      0.000000     4.000000
# ...

# %%
df.columns
# Out:
# Index(['student_id', 'age', 'gender', 'academic_level', 'study_hours',
#        'self_study_hours', 'online_classes_hours', 'social_media_hours',
#        'gaming_hours', 'sleep_hours', 'screen_time_hours', 'exercise_minutes',
#        'caffeine_intake_mg', 'part_time_job', 'upcoming_deadline',
#        'internet_quality', 'mental_health_score', 'focus_index',
#        'burnout_level', 'productivity_score', 'exam_score'],
#       dtype='object')

# %%
df.isnull().any().any()
# Out:
# np.False_

# %%
df.isnull().sum()
# Out:
# student_id              0
# age                     0
# gender                  0
# academic_level          0
# study_hours             0
# self_study_hours        0
# online_classes_hours    0
# social_media_hours      0
# gaming_hours            0
# sleep_hours             0
# screen_time_hours       0
# exercise_minutes        0
# caffeine_intake_mg      0
# part_time_job           0
# upcoming_deadline       0
# internet_quality        0
# mental_health_score     0
# focus_index             0
# burnout_level           0
# productivity_score      0
# exam_score              0
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [student_id, age, gender, academic_level, study_hours, self_study_hours, online_classes_hours, social_media_hours, gaming_hours, sleep_hours, screen_time_hours, exercise_minutes, caffeine_intake_mg, part_time_job, upcoming_deadline, internet_quality, mental_health_score, focus_index, burnout_level, productivity_score, exam_score]
# Index: []
#
# [0 rows x 21 columns]

# %%
X = df.drop(columns=['exam_score'])
y = df['exam_score']

# %%
X.head()
# Out:
#    student_id  age gender academic_level  study_hours  self_study_hours  \
# 0           1   18  Other    High School         7.64              1.56
# 1           2   18  Other    High School         2.21              2.22
# 2           3   22   Male    High School         3.45              0.00
# 3           4   17  Other    High School         5.75              2.08
# 4           5   19  Other    High School         6.83              1.72
#
#    online_classes_hours  social_media_hours  gaming_hours  sleep_hours  \
# 0                  2.20                3.05          2.19         6.52
# 1                  2.10                1.65          2.55         5.97
# 2                  0.29                1.34          2.08         8.39
# 3                  3.01                2.27          2.20         6.31
# 4                  3.33                2.65          0.70         8.01
#
#    screen_time_hours  exercise_minutes  caffeine_intake_mg  part_time_job  \
# ...

# %%
X = pd.get_dummies(X, dtype=int)

# %%
X.shape
# Out:
# (5000, 26)

# %%
X.head(5)
# Out:
#    student_id  age  study_hours  self_study_hours  online_classes_hours  \
# 0           1   18         7.64              1.56                  2.20
# 1           2   18         2.21              2.22                  2.10
# 2           3   22         3.45              0.00                  0.29
# 3           4   17         5.75              2.08                  3.01
# 4           5   19         6.83              1.72                  3.33
#
#    social_media_hours  gaming_hours  sleep_hours  screen_time_hours  \
# 0                3.05          2.19         6.52               6.47
# 1                1.65          2.55         5.97               6.05
# 2                1.34          2.08         8.39               7.62
# 3                2.27          2.20         6.31              11.67
# 4                2.65          0.70         8.01              10.02
#
#    exercise_minutes  ...  productivity_score  gender_Female  gender_Male  \
# ...

# %%
y.head()
# Out:
# 0    50.16
# 1     1.00
# 2    18.30
# 3     9.37
# 4    27.81
# Name: exam_score, dtype: float64

# %%
X.columns
# Out:
# Index(['student_id', 'age', 'study_hours', 'self_study_hours',
#        'online_classes_hours', 'social_media_hours', 'gaming_hours',
#        'sleep_hours', 'screen_time_hours', 'exercise_minutes',
#        'caffeine_intake_mg', 'part_time_job', 'upcoming_deadline',
#        'mental_health_score', 'focus_index', 'burnout_level',
#        'productivity_score', 'gender_Female', 'gender_Male', 'gender_Other',
#        'academic_level_High School', 'academic_level_Postgraduate',
#        'academic_level_Undergraduate', 'internet_quality_Average',
#        'internet_quality_Good', 'internet_quality_Poor'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train,y_test = train_test_split(X,y,train_size=0.7,random_state=42)

# %%
X_train.shape,X_test.shape
# Out:
# ((3500, 26), (1500, 26))

# %%
X_train.head()
# Out:
#       student_id  age  study_hours  self_study_hours  online_classes_hours  \
# 1840        1841   17         3.96              2.87                  0.31
# 2115        2116   16         6.94              1.04                  3.60
# 4437        4438   24         6.09              3.55                  4.73
# 1146        1147   17         7.78              2.22                  3.17
# 2486        2487   17         7.95              3.80                  1.39
#
#       social_media_hours  gaming_hours  sleep_hours  screen_time_hours  \
# 1840                2.62          2.63         5.86               6.05
# 2115                5.46          1.12         8.26               5.58
# 4437                2.87          1.42         4.69               6.49
# 1146                4.24          2.17         6.67               8.97
# 2486                3.00          1.82         6.92              10.51
#
#       exercise_minutes  ...  productivity_score  gender_Female  gender_Male  \
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler  = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train
# Out:
# array([[-0.47189175, -1.23291707, -0.32898634, ..., -0.70045009,
#          1.37310163, -0.69275929],
#        [-0.28001648, -1.58340519,  1.3038051 , ..., -0.70045009,
#          1.37310163, -0.69275929],
#        [ 1.34010849,  1.22049978,  0.838076  , ..., -0.70045009,
#         -0.72827821,  1.44350284],
#        ...,
#        [ 0.40166401, -1.23291707,  1.09011763, ..., -0.70045009,
#         -0.72827821,  1.44350284],
#        [ 0.87611921,  0.16903541, -0.21940302, ..., -0.70045009,
#         -0.72827821,  1.44350284],
#        [-1.15566543, -0.88242895, -0.32898634, ..., -0.70045009,
#         -0.72827821,  1.44350284]])

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

model = RandomForestRegressor(random_state=42)
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

print('Mean Squared Error:')
print(mean_squared_error(y_test, y_pred))
# Out:
# Mean Squared Error:
# 25.823733582779997

# %%
bins = [0, 10, 20, 40, 65]
labels = ['Fail', 'Pass', 'Good', 'Excellent']
y_classified = pd.cut(y, bins=bins, labels=labels, right=False)
print(y_classified.value_counts())
# Out:
# exam_score
# Good         1980
# Pass         1454
# Fail         1325
# Excellent     241
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train_cls, X_test_cls, y_train_cls, y_test_cls = train_test_split(X, y_classified, test_size=0.3, random_state=42)

X_train_cls = scaler.transform(X_train_cls)
X_test_cls = scaler.transform(X_test_cls)

print("Shape of X_train_cls:", X_train_cls.shape)
print("Shape of X_test_cls:", X_test_cls.shape)
print("Shape of y_train_cls:", y_train_cls.shape)
print("Shape of y_test_cls:", y_test_cls.shape)
# Out:
# Shape of X_train_cls: (3500, 26)
# Shape of X_test_cls: (1500, 26)
# Shape of y_train_cls: (3500,)
# Shape of y_test_cls: (1500,)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Initialize and train the RandomForestClassifier
model_cls = RandomForestClassifier(random_state=42)
model_cls.fit(X_train_cls, y_train_cls)

# Make predictions on the test set
y_pred_cls = model_cls.predict(X_test_cls)

# Evaluate the model
print("Accuracy Score:", accuracy_score(y_test_cls, y_pred_cls))
print("\nClassification Report:\n", classification_report(y_test_cls, y_pred_cls))
print("\nConfusion Matrix:\n", confusion_matrix(y_test_cls, y_pred_cls))
# Out:
# Accuracy Score: 0.736
#
# Classification Report:
#                precision    recall  f1-score   support
#
#    Excellent       0.81      0.34      0.48        65
#         Fail       0.81      0.76      0.78       410
#         Good       0.79      0.84      0.81       598
#         Pass       0.59      0.63      0.61       427
#
#     accuracy                           0.74      1500
#    macro avg       0.75      0.64      0.67      1500
# weighted avg       0.74      0.74      0.73      1500
#
#
# Confusion Matrix:
#  [[ 22   0  43   0]
#  [  0 311   5  94]
#  [  5   1 500  92]
#  [  0  73  83 271]]

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# Linear Kernel
svc_linear = SVC(kernel='linear', random_state=42)
svc_linear.fit(X_train_cls, y_train_cls)
y_pred_linear = svc_linear.predict(X_test_cls)
print(f"Accuracy Score with Linear Kernel: {accuracy_score(y_test_cls, y_pred_linear):.4f}")

# Sigmoid Kernel
svc_sigmoid = SVC(kernel='sigmoid', random_state=42)
svc_sigmoid.fit(X_train_cls, y_train_cls)
y_pred_sigmoid = svc_sigmoid.predict(X_test_cls)
print(f"Accuracy Score with Sigmoid Kernel: {accuracy_score(y_test_cls, y_pred_sigmoid):.4f}")

# Polynomial Kernel
svc_poly = SVC(kernel='poly', random_state=42)
svc_poly.fit(X_train_cls, y_train_cls)
y_pred_poly = svc_poly.predict(X_test_cls)
print(f"Accuracy Score with Polynomial Kernel: {accuracy_score(y_test_cls, y_pred_poly):.4f}")
# Out:
# Accuracy Score with Linear Kernel: 0.7400
# Accuracy Score with Sigmoid Kernel: 0.7333
# Accuracy Score with Polynomial Kernel: 0.6827
